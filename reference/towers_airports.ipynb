# %%
import pandas as pd

# %%
# airports = pd.read_json('http://api.travelpayouts.com/data/ru/airports.json')
airports[airports['code'] == 'LED']
# Out:
#    city_code code                         coordinates country_code  \
# 33       LED  LED  {'lon': 30.3083, 'lat': 59.806084}           RU
#
#     flightable     name          name_translations      time_zone
# 33        True  Пулково  {'en': 'Pulkovo Airport'}  Europe/Moscow

# %%
airports
# Out:
#       city_code code                                      coordinates  \
# 0           ANS  ANS           {'lon': -73.355835, 'lat': -13.716667}
# 1           RTW  GSV             {'lon': 46.166667, 'lat': 51.716667}
# 2           DKR  DSS            {'lon': -17.066944, 'lat': 14.671111}
# 3           INW  INW              {'lon': -110.725, 'lat': 35.024166}
# 4           NGR  NGR                      {'lon': 141.0, 'lat': -6.5}
# 5           BJS  PKX              {'lon': 116.41229, 'lat': 39.49746}
# 6           YFC  YFC              {'lon': -66.52978, 'lat': 45.87316}
# 7           IST  ISL             {'lon': 28.815277, 'lat': 40.976665}
# 8           YFE  YFE                {'lon': -69.066666, 'lat': 48.75}
# 9           MRU  MRU             {'lon': 57.67663, 'lat': -20.431997}
# 10          YKA  YKA            {'lon': -120.442024, 'lat': 50.70545}
# 11          NHA  NHA             {'lon': 109.19666, 'lat': 12.227912}
# ...

# %%
asia = pd.read_html('http://www.countryareacode.net/en/list-of-countries-according-to-continent/asia', attrs = {'id': 'countries'})[0]

# %%
africa = pd.read_html('http://www.countryareacode.net/en/list-of-countries-according-to-continent/africa', attrs = {'id': 'countries'})[0]

# %%
america = pd.read_html('http://www.countryareacode.net/en/list-of-countries-according-to-continent/america', attrs = {'id': 'countries'})[0]

# %%
australia_and_oceania = pd.read_html('http://www.countryareacode.net/en/list-of-countries-according-to-continent/australia-and-oceania', attrs = {'id': 'countries'})[0]

# %%
europe = pd.read_html('http://www.countryareacode.net/en/list-of-countries-according-to-continent/europe', attrs = {'id': 'countries'})[0]

# %%
africa
# Out:
#     Flag ISO code2 ISO code3                       Country  Capital city  \
# 0    NaN        DZ       DZA                       Algeria       Algiers
# 1    NaN        AO       AGO                        Angola        Luanda
# 2    NaN        BJ       BEN                         Benin    Porto-Novo
# 3    NaN        BW       BWA                      Botswana      Gaborone
# 4    NaN        BF       BFA                  Burkina Faso   Ouagadougou
# 5    NaN        BI       BDI                       Burundi     Bujumbura
# 6    NaN        CM       CMR                      Cameroon       Yaoundé
# 7    NaN        CV       CPV                    Cape Verde         Praia
# 8    NaN        CF       CAF      Central African Republic        Bangui
# 9    NaN        KM       COM                       Comoros        Moroni
# 10   NaN        CD       COD  Democratic Republic of Congo      Kinshasa
# 11   NaN        DJ       DJI                      Djibouti      Djibouti
# ...
