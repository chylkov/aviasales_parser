# %% [markdown]
# 0. в парсер добавить перебор длинных маршрутов
# 0. очистка ticket base после полной загрузки (удаление дублей)
# 0. умный перебор: смотреть если перелет из точки А в точку B и в точку C (если нет из B в C то А в B не нужно)
#
#
# 0. когда точек отправления 2 и более сделеать
# 0. умная фильтрация по столбцам (все одинаковые фичи шли подряд)
# 0. составление маршрутов когда 2 и более точек
# 0. при фильтрации добавить duration (когда сравниваю две даты)
# 0. реализовать систему весов для сортировки
# 0. киллер фича, это учет часовых поясов аэропортов, даты начала рейса, продолжительности для высчитывания во сколько ты прилетаешь
# 0. продумать как json дозаписывать
# 0. сделать нормальную функцию группировки
# 0. для умной генерации маршрутов нужно навесить кучу ограничений, например, такого не должно быть:
#
# [('KWE', 'TYN'), ('TYN', 'KWE'), ('KWE', 'PVG'), ('PVG', 'MOW')]

# %%
#!pip install selenium

# %%
# https://support.travelpayouts.com/hc/ru/categories/200358578-API-%D0%B8-%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%B5
# https://support.travelpayouts.com/hc/ru/articles/203956163-Aviasales-API-%D0%B4%D0%BE%D1%81%D1%82%D1%83%D0%BF%D0%B0-%D0%BA-%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%BC-%D0%B4%D0%BB%D1%8F-%D1%83%D1%87%D0%B0%D1%81%D1%82%D0%BD%D0%B8%D0%BA%D0%BE%D0%B2-%D0%BF%D0%B0%D1%80%D1%82%D0%BD%D0%B5%D1%80%D1%81%D0%BA%D0%BE%D0%B9-%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D1%8B#15

# %%
ACCESS_TOKEN = 'b8848ff67e92768d2d1977862372d796'

origin = ['KWE']#'KWE'
final_destination = ['LED', 'MOW'] #'LED' 'KLO'
range_date = ['2020-01-07', '2020-01-15']
number_place = 2

time_sleep = 3
date_start, date_end = range_date[0], range_date[1]

url = 'http://api.travelpayouts.com/v2/prices/month-matrix'

group = ['DME', 'SVO', 'VKO', 'ZIA']

wishful_point = []

# %%
import requests
import json
import codecs

from itertools import product
from tqdm import tqdm_notebook as tqdm

from datetime import datetime, timedelta
from time import sleep
import pandas as pd
from selenium import webdriver

add_zero = lambda x: '0' + str(x) if len(str(x)) < 2 else str(x)
# Используйте тут ваш путь к chromedriver!
chromedriver_path = 'chromedriver.exe'
driver = webdriver.Chrome(executable_path=chromedriver_path) # Этой командой открывается окно Chrome

# %%
df = pd.read_json('ticket_base.json')
df = df[(df['depart_date'] >= date_start) & (df['depart_date'] <= date_end)]

feature = list(df.columns).remove('found_at')

df.sort_values(by = 'found_at', ascending=False, inplace=True)
df.drop_duplicates(inplace = True, keep = 'first', subset = feature)

df.to_csv('routes_price.txt', index = False)

# %%
route_feature = ['depart_date', 'origin', 'destination', 'distance', 
                 'duration', 'number_of_changes', 'value']

df_route = df[df['origin'].isin(origin)][route_feature]

for change in range(number_place):
    
    if change == 0:
        df_route = df_route.merge(df[route_feature], 
                                           how = 'left', left_on = 'destination', 
                                           right_on = 'origin', suffixes = ['_from', ''])
        
        df_route.rename(columns={x:x + '_' + str(change + 1) for x in route_feature}, inplace = True)

        df_route = df_route[df_route['depart_date_from'] <= df_route['depart_date_' + str(change + 1)]]
    else:
        df_route = df_route.merge(df[route_feature], 
                                           how = 'left', left_on = 'destination_' + str(change), 
                                           right_on = 'origin')
        
        df_route.rename(columns={x:x + '_' + str(change + 1) for x in route_feature}, inplace = True)
        df_route = df_route[df_route['depart_date_' + str(change)] <= df_route['depart_date_' + str(change+1)]]


value_list = list(filter(lambda x: x[:5] == 'value', list(df_route.columns)))
df_route['total_value'] =  df_route[value_list].sum(axis = 1)

#df_route = df_route[(df_route['depart_date_from'] >= date_start) & (df_route['depart_date_to'] <= date_end)]

df_route.sort_values(by = ['total_value', 'depart_date_from'] , inplace = True)

df_route = df_route[df_route['destination_' + str(change+1)].isin(final_destination)]

df_route.reset_index(drop=True, inplace = True)

# %%
df_route
# Out:
# Empty DataFrame
# Columns: [depart_date_from, origin_from, destination_from, distance_from, duration_from, number_of_changes_from, value_from, depart_date_1, origin_1, destination_1, distance_1, duration_1, number_of_changes_1, value_1, depart_date_2, origin_2, destination_2, distance_2, duration_2, number_of_changes_2, value_2, total_value]
# Index: []
#
# [0 rows x 22 columns]

# %%
d =[1, 2, 3]

# %%
d[-1:]
# Out:
# [3]

# %%
url_routes = 'http://api.travelpayouts.com/data/routes.json'
routes = json.loads(requests.get(url_routes).text)
route_chain = list(map(lambda x: [x['departure_airport_iata'], x['arrival_airport_iata']], routes))

def group_airport(route, group):
    if route[1] in group: route[1] = 'MOW'
    if route[0] in group: route[0] = 'MOW'
    return route

route_chain = list(map(lambda x: group_airport(x, group), route_chain))
route_chain = list(set(map(lambda x: tuple(x), route_chain)))

# %%
def get_next_chain(arrivals, route_chain, final_destination, final = False):
    if final:
        next_chain = filter(lambda x: (x[0] in arrivals) & (x[1] in final_destination), route_chain)
    else:
        next_chain = filter(lambda x: x[0] in arrivals, route_chain)
    return next_chain

def get_arrivals(required_routes):
    if type(required_routes[0][0]) == str:
        arrivals = list(map(lambda x: x[1], required_routes))
    else: 
        arrivals = list(set(map(lambda x: x[-1][1], required_routes)))
    return arrivals

def get_product(required_routes, next_chain):
    if type(required_routes[0][0]) == str:
        required_routes = list(filter(lambda x: x[-2][1] == x[-1][0], product(required_routes, next_chain)))
    else: 
        required_routes = list(filter(lambda x: x[-2][-1][1] == x[-1][0], product(required_routes, next_chain)))
    return required_routes

def get_routes(origin, final_destination, route_chain, number_flights = 4):
    if number_flights == 1:
        required_routes = list(set(filter(lambda x: (x[0] in origin) & (x[1] in final_destination), route_chain)))
    else:
        required_routes = list(set(filter(lambda x: x[0] in origin, route_chain)))
        for n in range(1, number_flights):
            arrivals = get_arrivals(required_routes)
            if n + 1 == number_flights:
                next_chain = get_next_chain(arrivals, route_chain, final_destination, True)
            else:    
                next_chain = get_next_chain(arrivals, route_chain, final_destination)
            required_routes = get_product(required_routes, next_chain)           
    return required_routes

def delete_chains(final_destination, rout):
    s = 1
    for chain in rout:
        if chain[-1] not in final_destination:
            s = s + 1
        else:
            break
    rout = rout[:s]
    return rout
            
def flat_route(route):
    root = route
    result = []
    while type(root[-2]) != str:
        result.append(root[-1])
        root = root[-2]
        
    result.append(root)
    result.reverse()
    return result

# %%
required_routes = get_routes(origin, final_destination, route_chain, number_flights = 4)
required_routes = list(map(flat_route, required_routes))
required_routes = list(map(lambda x: delete_chains(final_destination, x), required_routes))

# %%
f = codecs.open('airports.json', encoding='utf-8', mode='r')
data = json.load(f)

# %%
all_points = list(set([point for route in required_routes for chain in route for point in chain]))

# %%
list(filter(lambda x: ((x['city_code'] in all_points) 
                               or (x['code'] in all_points)) and (x['country_code'] not in ['RU']), data))
# Out:
# [{'time_zone': 'Europe/Istanbul',
#   'name': 'Ататюрк',
#   'flightable': False,
#   'coordinates': {'lon': 28.815277, 'lat': 40.976665},
#   'code': 'ISL',
#   'name_translations': {'en': 'Istanbul Ataturk Airport'},
#   'country_code': 'TR',
#   'city_code': 'IST'},
#  {'time_zone': 'Indian/Mauritius',
#   'name': 'Сивусагур Рамгулам\xa0',
#   'flightable': True,
#   'coordinates': {'lon': 57.67663, 'lat': -20.431997},
#   'code': 'MRU',
#   'name_translations': {'en': 'Sir Seewoosagur Ramgoolam International Airport'},
#   'country_code': 'MU',
#   'city_code': 'MRU'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Железнодорожная станция Даньян',
#   'flightable': False,
#   'coordinates': {'lon': 0.0, 'lat': 0.0},
#   'code': 'DYN',
#   'name_translations': {'en': 'Danyang Railway Station'},
#   'country_code': 'CN',
#   'city_code': 'SHA'},
#  {'time_zone': 'Europe/Simferopol',
#   'name': 'Симферополь',
#   'flightable': True,
#   'coordinates': {'lon': 33.99819, 'lat': 45.020657},
#   'code': 'SIP',
#   'name_translations': {'en': 'Simferopol International Airport'},
#   'country_code': 'KX',
#   'city_code': 'SIP'},
#  {'time_zone': 'Europe/Helsinki',
#   'name': 'Хельсинки (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 24.941389, 'lat': 60.171944},
#   'code': 'HEC',
#   'name_translations': {'en': 'Helsinki Central Station'},
#   'country_code': 'FI',
#   'city_code': 'HEL'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Южная железнодорожная станция Куншан',
#   'flightable': False,
#   'coordinates': {'lon': 0.0, 'lat': 0.0},
#   'code': 'KVN',
#   'name_translations': {'en': 'Kunshan South Railway Station'},
#   'country_code': 'CN',
#   'city_code': 'SHA'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Железнодорожная станция Сюйчжоу',
#   'flightable': False,
#   'coordinates': {'lon': 0.0, 'lat': 0.0},
#   'code': 'XUK',
#   'name_translations': {'en': 'Xuzhou Railway Station'},
#   'country_code': 'CN',
#   'city_code': 'XUZ'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Железнодорожная станция Нанкин',
#   'flightable': False,
#   'coordinates': {'lon': 0.0, 'lat': 0.0},
#   'code': 'NKJ',
#   'name_translations': {'en': 'Nanjing South Railway Station'},
#   'country_code': 'CN',
#   'city_code': 'NKG'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Нинбо',
#   'flightable': True,
#   'coordinates': {'lon': 121.462395, 'lat': 29.820415},
#   'code': 'NGB',
#   'name_translations': {'en': 'Ningbo Airport'},
#   'country_code': 'CN',
#   'city_code': 'NGB'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Железнодорожная станция Иу',
#   'flightable': False,
#   'coordinates': {'lon': 0.0, 'lat': 0.0},
#   'code': 'YIU',
#   'name_translations': {'en': 'Yiwu Railway Station'},
#   'country_code': 'CN',
#   'city_code': 'YIW'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Чубу',
#   'flightable': True,
#   'coordinates': {'lon': 136.80528, 'lat': 34.858334},
#   'code': 'NGO',
#   'name_translations': {'en': 'Chubu Centrair International Airport'},
#   'country_code': 'JP',
#   'city_code': 'NGO'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Нагасаки',
#   'flightable': True,
#   'coordinates': {'lon': 129.92258, 'lat': 32.9144},
#   'code': 'NGS',
#   'name_translations': {'en': 'Nagasaki Airport'},
#   'country_code': 'JP',
#   'city_code': 'NGS'},
#  {'time_zone': 'Asia/Tashkent',
#   'name': 'Ташкент',
#   'flightable': True,
#   'coordinates': {'lon': 69.26619, 'lat': 41.262714},
#   'code': 'TAS',
#   'name_translations': {'en': 'Yuzhny Airport'},
#   'country_code': 'UZ',
#   'city_code': 'TAS'},
#  {'time_zone': 'Asia/Bangkok',
#   'name': 'Суварнабхуми',
#   'flightable': True,
#   'coordinates': {'lon': 100.752045, 'lat': 13.693062},
#   'code': 'BKK',
#   'name_translations': {'en': 'Suvarnabhumi Airport'},
#   'country_code': 'TH',
#   'city_code': 'BKK'},
#  {'time_zone': 'America/Cancun',
#   'name': 'Канкун',
#   'flightable': True,
#   'coordinates': {'lon': -86.874435, 'lat': 21.040457},
#   'code': 'CUN',
#   'name_translations': {'en': 'Cancun International Airport'},
#   'country_code': 'MX',
#   'city_code': 'CUN'},
#  {'time_zone': 'Asia/Dushanbe',
#   'name': 'Душанбе',
#   'flightable': True,
#   'coordinates': {'lon': 68.81728, 'lat': 38.54894},
#   'code': 'DYU',
#   'name_translations': {'en': 'Dushanbe Airport'},
#   'country_code': 'TJ',
#   'city_code': 'DYU'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Мэйсянь',
#   'flightable': True,
#   'coordinates': {'lon': 116.10449, 'lat': 24.266811},
#   'code': 'MXZ',
#   'name_translations': {'en': 'Mei Xian Airport'},
#   'country_code': 'CN',
#   'city_code': 'MXZ'},
#  {'time_zone': 'Asia/Seoul',
#   'name': 'Инчеон',
#   'flightable': True,
#   'coordinates': {'lon': 126.45123, 'lat': 37.448524},
#   'code': 'ICN',
#   'name_translations': {'en': 'Incheon International Airport'},
#   'country_code': 'KR',
#   'city_code': 'SEL'},
#  {'time_zone': 'Europe/Amsterdam',
#   'name': 'Схипхол',
#   'flightable': True,
#   'coordinates': {'lon': 4.763385, 'lat': 52.30907},
#   'code': 'AMS',
#   'name_translations': {'en': 'Amsterdam Airport Schiphol'},
#   'country_code': 'NL',
#   'city_code': 'AMS'},
#  {'time_zone': 'Asia/Tbilisi',
#   'name': 'Батуми',
#   'flightable': True,
#   'coordinates': {'lon': 41.600555, 'lat': 41.610832},
#   'code': 'BUS',
#   'name_translations': {'en': 'Batumi Airport'},
#   'country_code': 'GE',
#   'city_code': 'BUS'},
#  {'time_zone': 'Europe/Athens',
#   'name': 'Салоники',
#   'flightable': True,
#   'coordinates': {'lon': 22.972221, 'lat': 40.520832},
#   'code': 'SKG',
#   'name_translations': {'en': 'Thessaloniki International Airport'},
#   'country_code': 'GR',
#   'city_code': 'SKG'},
#  {'time_zone': 'Pacific/Guam',
#   'name': 'Гуам',
#   'flightable': True,
#   'coordinates': {'lon': 144.80486, 'lat': 13.492787},
#   'code': 'GUM',
#   'name_translations': {'en': 'A.B. Won Pat International Airport'},
#   'country_code': 'GU',
#   'city_code': 'GUM'},
#  {'time_zone': 'Europe/Berlin',
#   'name': 'Франкфурт-на-Майне',
#   'flightable': True,
#   'coordinates': {'lon': 8.570773, 'lat': 50.050735},
#   'code': 'FRA',
#   'name_translations': {'en': 'Frankfurt Airport'},
#   'country_code': 'DE',
#   'city_code': 'FRA'},
#  {'time_zone': 'Europe/Paris',
#   'name': "Кот Д'Азур",
#   'flightable': True,
#   'coordinates': {'lon': 7.205232, 'lat': 43.66049},
#   'code': 'NCE',
#   'name_translations': {'en': "Cote D'Azur Airport"},
#   'country_code': 'FR',
#   'city_code': 'NCE'},
#  {'time_zone': 'Europe/Berlin',
#   'name': 'Шенефельд',
#   'flightable': True,
#   'coordinates': {'lon': 13.521388, 'lat': 52.370277},
#   'code': 'SXF',
#   'name_translations': {'en': 'Schonefeld Airport'},
#   'country_code': 'DE',
#   'city_code': 'BER'},
#  {'time_zone': 'Europe/Kiev',
#   'name': 'Одесса',
#   'flightable': True,
#   'coordinates': {'lon': 30.676718, 'lat': 46.44101},
#   'code': 'ODS',
#   'name_translations': {'en': 'Odessa International Airport'},
#   'country_code': 'UA',
#   'city_code': 'ODS'},
#  {'time_zone': 'Atlantic/Canary',
#   'name': 'Тенерифе Южный',
#   'flightable': True,
#   'coordinates': {'lon': -16.5725, 'lat': 28.044443},
#   'code': 'TFS',
#   'name_translations': {'en': 'Tenerife South Airport'},
#   'country_code': 'ES',
#   'city_code': 'TCI'},
#  {'time_zone': 'Europe/Rome',
#   'name': 'Марко Поло',
#   'flightable': True,
#   'coordinates': {'lon': 12.337947, 'lat': 45.502285},
#   'code': 'VCE',
#   'name_translations': {'en': 'Venice Marco Polo Airport'},
#   'country_code': 'IT',
#   'city_code': 'VCE'},
#  {'time_zone': 'Europe/Stockholm',
#   'name': 'Арланда',
#   'flightable': True,
#   'coordinates': {'lon': 17.930365, 'lat': 59.64982},
#   'code': 'ARN',
#   'name_translations': {'en': 'Stockholm Arlanda Airport'},
#   'country_code': 'SE',
#   'city_code': 'STO'},
#  {'time_zone': 'Asia/Dushanbe',
#   'name': 'Куляб',
#   'flightable': True,
#   'coordinates': {'lon': 69.80666, 'lat': 37.988335},
#   'code': 'TJU',
#   'name_translations': {'en': 'Kulyab Airport'},
#   'country_code': 'TJ',
#   'city_code': 'TJU'},
#  {'time_zone': 'Europe/Berlin',
#   'name': 'Кельн-Бонн',
#   'flightable': True,
#   'coordinates': {'lon': 7.122224, 'lat': 50.878365},
#   'code': 'CGN',
#   'name_translations': {'en': 'Cologne Bonn Airport'},
#   'country_code': 'DE',
#   'city_code': 'CGN'},
#  {'time_zone': 'Africa/Cairo',
#   'name': 'Каир',
#   'flightable': True,
#   'coordinates': {'lon': 31.40647, 'lat': 30.120106},
#   'code': 'CAI',
#   'name_translations': {'en': 'Cairo International Airport'},
#   'country_code': 'EG',
#   'city_code': 'CAI'},
#  {'time_zone': 'Europe/Zurich',
#   'name': 'Цюрих',
#   'flightable': True,
#   'coordinates': {'lon': 8.561746, 'lat': 47.450603},
#   'code': 'ZRH',
#   'name_translations': {'en': 'Zurich Airport'},
#   'country_code': 'CH',
#   'city_code': 'ZRH'},
#  {'time_zone': 'Europe/Rome',
#   'name': 'Тревизо',
#   'flightable': True,
#   'coordinates': {'lon': 12.204444, 'lat': 45.655113},
#   'code': 'TSF',
#   'name_translations': {'en': 'Treviso Airport'},
#   'country_code': 'IT',
#   'city_code': 'VCE'},
#  {'time_zone': 'Asia/Yerevan',
#   'name': 'Ереван (стадион)',
#   'flightable': True,
#   'coordinates': {'lon': 44.5011413, 'lat': 40.1762089},
#   'code': 'XAA',
#   'name_translations': {'en': 'Yerevan Stadium'},
#   'country_code': 'AM',
#   'city_code': 'EVN'},
#  {'time_zone': 'Asia/Jerusalem',
#   'name': 'Эйлат',
#   'flightable': False,
#   'coordinates': {'lon': 34.9339, 'lat': 29.952015},
#   'code': 'VDA',
#   'name_translations': {'en': 'Ovda Airport'},
#   'country_code': 'IL',
#   'city_code': 'ETH'},
#  {'time_zone': 'Europe/Tallinn',
#   'name': 'Юлемисте',
#   'flightable': True,
#   'coordinates': {'lon': 24.798702, 'lat': 59.416622},
#   'code': 'TLL',
#   'name_translations': {'en': 'Tallinn Airport'},
#   'country_code': 'EE',
#   'city_code': 'TLL'},
#  {'time_zone': 'Europe/Kiev',
#   'name': 'Харьков',
#   'flightable': True,
#   'coordinates': {'lon': 36.281185, 'lat': 49.92078},
#   'code': 'HRK',
#   'name_translations': {'en': 'Kharkov Airport'},
#   'country_code': 'UA',
#   'city_code': 'HRK'},
#  {'time_zone': 'Asia/Nicosia',
#   'name': 'Пафос',
#   'flightable': True,
#   'coordinates': {'lon': 32.489105, 'lat': 34.71155},
#   'code': 'PFO',
#   'name_translations': {'en': 'Paphos International Airport'},
#   'country_code': 'CY',
#   'city_code': 'PFO'},
#  {'time_zone': 'Asia/Dubai',
#   'name': 'Аль-Мактум',
#   'flightable': True,
#   'coordinates': {'lon': 55.175278, 'lat': 24.918056},
#   'code': 'DWC',
#   'name_translations': {'en': 'Dubai World Central - Al Maktoum International Airport'},
#   'country_code': 'AE',
#   'city_code': 'DXB'},
#  {'time_zone': 'Australia/Sydney',
#   'name': 'Кингсфорд Смит',
#   'flightable': True,
#   'coordinates': {'lon': 151.1799, 'lat': -33.932922},
#   'code': 'SYD',
#   'name_translations': {'en': 'Sydney (Kingsford Smith) Airport'},
#   'country_code': 'AU',
#   'city_code': 'SYD'},
#  {'time_zone': 'Europe/Istanbul',
#   'name': 'Эсенбога',
#   'flightable': True,
#   'coordinates': {'lon': 32.993145, 'lat': 40.11494},
#   'code': 'ESB',
#   'name_translations': {'en': 'Esenboga International Airport'},
#   'country_code': 'TR',
#   'city_code': 'ANK'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Санья',
#   'flightable': True,
#   'coordinates': {'lon': 109.409706, 'lat': 18.31063},
#   'code': 'SYX',
#   'name_translations': {'en': 'Sanya Phoenix International Airport'},
#   'country_code': 'CN',
#   'city_code': 'SYX'},
#  {'time_zone': 'America/Toronto',
#   'name': 'Пирсон',
#   'flightable': True,
#   'coordinates': {'lon': -79.61146, 'lat': 43.681583},
#   'code': 'YYZ',
#   'name_translations': {'en': 'Pearson International Airport'},
#   'country_code': 'CA',
#   'city_code': 'YTO'},
#  {'time_zone': 'Europe/Zagreb',
#   'name': 'Загреб',
#   'flightable': True,
#   'coordinates': {'lon': 16.06152, 'lat': 45.733242},
#   'code': 'ZAG',
#   'name_translations': {'en': 'Zagreb International Airport'},
#   'country_code': 'HR',
#   'city_code': 'ZAG'},
#  {'time_zone': 'Europe/Brussels',
#   'name': 'Брюссель',
#   'flightable': True,
#   'coordinates': {'lon': 4.483602, 'lat': 50.89717},
#   'code': 'BRU',
#   'name_translations': {'en': 'Brussels Airport'},
#   'country_code': 'BE',
#   'city_code': 'BRU'},
#  {'time_zone': 'America/Vancouver',
#   'name': 'Ванкувер',
#   'flightable': True,
#   'coordinates': {'lon': -123.17919, 'lat': 49.1947},
#   'code': 'YVR',
#   'name_translations': {'en': 'Vancouver International Airport'},
#   'country_code': 'CA',
#   'city_code': 'YVR'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Баотоу',
#   'flightable': True,
#   'coordinates': {'lon': 110.0009, 'lat': 40.563328},
#   'code': 'BAV',
#   'name_translations': {'en': 'Baotou Airport'},
#   'country_code': 'CN',
#   'city_code': 'BAV'},
#  {'time_zone': 'Asia/Aqtobe',
#   'name': 'Актобе',
#   'flightable': True,
#   'coordinates': {'lon': 57.211403, 'lat': 50.249336},
#   'code': 'AKX',
#   'name_translations': {'en': 'Aktyubinsk Airport'},
#   'country_code': 'KZ',
#   'city_code': 'AKX'},
#  {'time_zone': 'Australia/Melbourne',
#   'name': 'Тулламарин',
#   'flightable': True,
#   'coordinates': {'lon': 144.84978, 'lat': -37.669613},
#   'code': 'MEL',
#   'name_translations': {'en': 'Tullamarine Airport'},
#   'country_code': 'AU',
#   'city_code': 'MEL'},
#  {'time_zone': 'Asia/Qatar',
#   'name': 'Доха',
#   'flightable': True,
#   'coordinates': {'lon': 51.558067, 'lat': 25.267569},
#   'code': 'DOH',
#   'name_translations': {'en': 'Hamad International Airport'},
#   'country_code': 'QA',
#   'city_code': 'DOH'},
#  {'time_zone': 'Asia/Almaty',
#   'name': 'Павлодар',
#   'flightable': True,
#   'coordinates': {'lon': 77.066666, 'lat': 52.183334},
#   'code': 'PWQ',
#   'name_translations': {'en': 'Pavlodar Airport'},
#   'country_code': 'KZ',
#   'city_code': 'PWQ'},
#  {'time_zone': 'Asia/Almaty',
#   'name': 'Бурундай',
#   'flightable': False,
#   'coordinates': {'lon': 76.95, 'lat': 43.5},
#   'code': 'BXJ',
#   'name_translations': {'en': 'Burundai'},
#   'country_code': 'KZ',
#   'city_code': 'ALA'},
#  {'time_zone': 'Europe/Stockholm',
#   'name': 'Ландветтер',
#   'flightable': True,
#   'coordinates': {'lon': 12.294878, 'lat': 57.66664},
#   'code': 'GOT',
#   'name_translations': {'en': 'Goteborg Landvetter Airport'},
#   'country_code': 'SE',
#   'city_code': 'GOT'},
#  {'time_zone': 'Asia/Seoul',
#   'name': 'Чеджу',
#   'flightable': True,
#   'coordinates': {'lon': 126.49312, 'lat': 33.5067},
#   'code': 'CJU',
#   'name_translations': {'en': 'Jeju International Airport'},
#   'country_code': 'KR',
#   'city_code': 'CJU'},
#  {'time_zone': 'America/Detroit',
#   'name': 'Вайн',
#   'flightable': True,
#   'coordinates': {'lon': -83.35605, 'lat': 42.20781},
#   'code': 'DTW',
#   'name_translations': {'en': 'Detroit Metropolitan Wayne County Airport'},
#   'country_code': 'US',
#   'city_code': 'DTT'},
#  {'time_zone': 'America/Los_Angeles',
#   'name': 'Боинг-Филд',
#   'flightable': True,
#   'coordinates': {'lon': -122.3037, 'lat': 47.5371},
#   'code': 'BFI',
#   'name_translations': {'en': 'Boeing Field International Airport'},
#   'country_code': 'US',
#   'city_code': 'SEA'},
#  {'time_zone': 'Asia/Tashkent',
#   'name': 'Андижан',
#   'flightable': True,
#   'coordinates': {'lon': 72.3, 'lat': 40.733334},
#   'code': 'AZN',
#   'name_translations': {'en': 'Andizhan Airport'},
#   'country_code': 'UZ',
#   'city_code': 'AZN'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Наха',
#   'flightable': True,
#   'coordinates': {'lon': 127.645836, 'lat': 26.195833},
#   'code': 'OKA',
#   'name_translations': {'en': 'Naha Airport'},
#   'country_code': 'JP',
#   'city_code': 'OKA'},
#  {'time_zone': 'Europe/Berlin',
#   'name': 'Ганновер (автовокзал)',
#   'flightable': True,
#   'coordinates': {'lon': -92.13008, 'lat': 35.61689},
#   'code': 'HBZ',
#   'name_translations': {'en': 'Hannover Bus Station'},
#   'country_code': 'DE',
#   'city_code': 'HAJ'},
#  {'time_zone': 'Asia/Dubai',
#   'name': 'Дубай (автовокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 55.3116667, 'lat': 25.2644444},
#   'code': 'XNB',
#   'name_translations': {'en': 'Chelsea Twr EY Bus Station'},
#   'country_code': 'AE',
#   'city_code': 'DXB'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Пекин',
#   'flightable': True,
#   'coordinates': {'lon': 116.5871, 'lat': 40.078537},
#   'code': 'PEK',
#   'name_translations': {'en': 'Beijing Capital International Airport'},
#   'country_code': 'CN',
#   'city_code': 'BJS'},
#  {'time_zone': 'Europe/Paris',
#   'name': 'Шарль де Голль',
#   'flightable': True,
#   'coordinates': {'lon': 2.567023, 'lat': 49.003197},
#   'code': 'CDG',
#   'name_translations': {'en': 'Charles de Gaulle Airport'},
#   'country_code': 'FR',
#   'city_code': 'PAR'},
#  {'time_zone': 'Asia/Phnom_Penh',
#   'name': 'Сиемреап',
#   'flightable': True,
#   'coordinates': {'lon': 103.815926, 'lat': 13.408436},
#   'code': 'REP',
#   'name_translations': {'en': 'Siem Reap International Airport'},
#   'country_code': 'KH',
#   'city_code': 'REP'},
#  {'time_zone': 'Asia/Macau',
#   'name': 'Макао',
#   'flightable': True,
#   'coordinates': {'lon': 113.57285, 'lat': 22.156588},
#   'code': 'MFM',
#   'name_translations': {'en': 'Macau International Airport'},
#   'country_code': 'MO',
#   'city_code': 'MFM'},
#  {'time_zone': 'Asia/Seoul',
#   'name': 'Гимпо',
#   'flightable': True,
#   'coordinates': {'lon': 126.80351, 'lat': 37.559288},
#   'code': 'GMP',
#   'name_translations': {'en': 'Gimpo International Airport'},
#   'country_code': 'KR',
#   'city_code': 'SEL'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Ухань',
#   'flightable': True,
#   'coordinates': {'lon': 114.209625, 'lat': 30.776598},
#   'code': 'WUH',
#   'name_translations': {'en': 'Wuhan Tianhe International Airport'},
#   'country_code': 'CN',
#   'city_code': 'WUH'},
#  {'time_zone': 'Asia/Seoul',
#   'name': 'Тэгу',
#   'flightable': True,
#   'coordinates': {'lon': 128.63788, 'lat': 35.899254},
#   'code': 'TAE',
#   'name_translations': {'en': 'Daegu International Airport'},
#   'country_code': 'KR',
#   'city_code': 'TAE'},
#  {'time_zone': 'Asia/Vientiane',
#   'name': 'Вьентьян',
#   'flightable': True,
#   'coordinates': {'lon': 102.56772, 'lat': 17.975431},
#   'code': 'VTE',
#   'name_translations': {'en': 'Wattay International Airport'},
#   'country_code': 'LA',
#   'city_code': 'VTE'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Чандэ',
#   'flightable': True,
#   'coordinates': {'lon': 111.63886, 'lat': 28.924467},
#   'code': 'CGD',
#   'name_translations': {'en': 'Changde Airport'},
#   'country_code': 'CN',
#   'city_code': 'CGD'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Сямынь',
#   'flightable': True,
#   'coordinates': {'lon': 118.1275, 'lat': 24.536882},
#   'code': 'XMN',
#   'name_translations': {'en': 'Xiamen Gaoqi International Airport'},
#   'country_code': 'CN',
#   'city_code': 'XMN'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Чанчунь',
#   'flightable': True,
#   'coordinates': {'lon': 125.217545, 'lat': 43.902836},
#   'code': 'CGQ',
#   'name_translations': {'en': 'Changchun Longjia International Airport'},
#   'country_code': 'CN',
#   'city_code': 'CGQ'},
#  {'time_zone': 'Europe/Oslo',
#   'name': 'Осло (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 10.7522454, 'lat': 59.9138688},
#   'code': 'XZO',
#   'name_translations': {'en': 'Oslo S Railway Station'},
#   'country_code': 'NO',
#   'city_code': 'OSL'},
#  {'time_zone': 'Europe/Brussels',
#   'name': 'Брюссель (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': -1.0, 'lat': -1.0},
#   'code': 'ZYR',
#   'name_translations': {'en': 'Midi Railway Station'},
#   'country_code': 'BE',
#   'city_code': 'BRU'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Чифэн',
#   'flightable': True,
#   'coordinates': {'lon': 118.91089, 'lat': 42.237392},
#   'code': 'CIF',
#   'name_translations': {'en': 'Chifeng Airport'},
#   'country_code': 'CN',
#   'city_code': 'CIF'},
#  {'time_zone': 'Asia/Colombo',
#   'name': 'Бандаранаике',
#   'flightable': True,
#   'coordinates': {'lon': 79.8865, 'lat': 7.174112},
#   'code': 'CMB',
#   'name_translations': {'en': 'Bandaranaike International Airport'},
#   'country_code': 'LK',
#   'city_code': 'CMB'},
#  {'time_zone': 'Australia/Sydney',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 151.2070914, 'lat': -33.8689009},
#   'code': 'XYS',
#   'name_translations': {'en': 'Sydney Ferry Port'},
#   'country_code': 'AU',
#   'city_code': 'SYD'},
#  {'time_zone': 'Europe/Amsterdam',
#   'name': 'Амстердам (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 4.8922222, 'lat': 52.3730556},
#   'code': 'ZYA',
#   'name_translations': {'en': 'Amsterdam Centraal Railway Station'},
#   'country_code': 'NL',
#   'city_code': 'AMS'},
#  {'time_zone': 'Africa/Casablanca',
#   'name': 'Мохаммед V',
#   'flightable': True,
#   'coordinates': {'lon': -7.586667, 'lat': 33.36667},
#   'code': 'CMN',
#   'name_translations': {'en': 'Mohamed V International Airport'},
#   'country_code': 'MA',
#   'city_code': 'CAS'},
#  {'time_zone': 'America/Tijuana',
#   'name': 'Генерал Абелардо Л. Родригес',
#   'flightable': True,
#   'coordinates': {'lon': -116.97466, 'lat': 32.546284},
#   'code': 'TIJ',
#   'name_translations': {'en': 'Tijuana Airport'},
#   'country_code': 'MX',
#   'city_code': 'TIJ'},
#  {'time_zone': 'Asia/Karachi',
#   'name': 'Исламабад',
#   'flightable': True,
#   'coordinates': {'lon': 72.83417, 'lat': 33.55429},
#   'code': 'ISB',
#   'name_translations': {'en': 'Islamabad International Airport'},
#   'country_code': 'PK',
#   'city_code': 'ISB'},
#  {'time_zone': 'Asia/Dubai',
#   'name': 'Абу-Даби (автовокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 54.3666667, 'lat': 24.4666667},
#   'code': 'ZVJ',
#   'name_translations': {'en': 'EK Bus Station'},
#   'country_code': 'AE',
#   'city_code': 'AUH'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Даюн',
#   'flightable': True,
#   'coordinates': {'lon': 110.44569, 'lat': 29.10712},
#   'code': 'DYG',
#   'name_translations': {'en': 'Zhangjiajie Hehua Airport'},
#   'country_code': 'CN',
#   'city_code': 'DYG'},
#  {'time_zone': 'Europe/Prague',
#   'name': 'Прага (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 14.4204598, 'lat': 50.0878114},
#   'code': 'XYJ',
#   'name_translations': {'en': 'Holesovice Railway Station'},
#   'country_code': 'CZ',
#   'city_code': 'PRG'},
#  {'time_zone': 'Pacific/Auckland',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 174.7633315, 'lat': -36.8484597},
#   'code': 'XNZ',
#   'name_translations': {'en': 'Auckland Ferry Port'},
#   'country_code': 'NZ',
#   'city_code': 'AKL'},
#  {'time_zone': 'Europe/Budapest',
#   'name': 'Будапешт (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 19.0407578, 'lat': 47.4984056},
#   'code': 'XXJ',
#   'name_translations': {'en': 'Deli Railway Station'},
#   'country_code': 'HU',
#   'city_code': 'BUD'},
#  {'time_zone': 'Australia/Adelaide',
#   'name': 'Аделаида',
#   'flightable': True,
#   'coordinates': {'lon': 138.53735, 'lat': -34.938175},
#   'code': 'ADL',
#   'name_translations': {'en': 'Adelaide Airport'},
#   'country_code': 'AU',
#   'city_code': 'ADL'},
#  {'time_zone': 'Asia/Karachi',
#   'name': 'Хаид-Эль-Азам',
#   'flightable': True,
#   'coordinates': {'lon': 67.16828, 'lat': 24.899986},
#   'code': 'KHI',
#   'name_translations': {'en': 'Jinnah International Airport'},
#   'country_code': 'PK',
#   'city_code': 'KHI'},
#  {'time_zone': 'Asia/Jakarta',
#   'name': 'Сурабая',
#   'flightable': True,
#   'coordinates': {'lon': 112.77724, 'lat': -7.38387},
#   'code': 'SUB',
#   'name_translations': {'en': 'Juanda International Airport'},
#   'country_code': 'ID',
#   'city_code': 'SUB'},
#  {'time_zone': 'Asia/Colombo',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 79.848358, 'lat': 6.927468},
#   'code': 'BYV',
#   'name_translations': {'en': 'Beira Lake SPB'},
#   'country_code': 'LK',
#   'city_code': 'CMB'},
#  {'time_zone': 'Europe/Madrid',
#   'name': 'Малага',
#   'flightable': True,
#   'coordinates': {'lon': -4.489616, 'lat': 36.675182},
#   'code': 'AGP',
#   'name_translations': {'en': 'Malaga Airport'},
#   'country_code': 'ES',
#   'city_code': 'AGP'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 127.65, 'lat': 26.2},
#   'code': 'AHA',
#   'name_translations': {'en': 'Naha AFB'},
#   'country_code': 'JP',
#   'city_code': 'OKA'},
#  {'time_zone': 'Asia/Dubai',
#   'name': 'Дубай (автовокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 55.3116667, 'lat': 25.2644444},
#   'code': 'XEU',
#   'name_translations': {'en': 'Hyatt Rgncy EY Bus Station'},
#   'country_code': 'AE',
#   'city_code': 'DXB'},
#  {'time_zone': 'Asia/Brunei',
#   'name': 'Бруней',
#   'flightable': True,
#   'coordinates': {'lon': 114.93375, 'lat': 4.945197},
#   'code': 'BWN',
#   'name_translations': {'en': 'Brunei International Airport'},
#   'country_code': 'BN',
#   'city_code': 'BWN'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Даньдун',
#   'flightable': True,
#   'coordinates': {'lon': 124.28081, 'lat': 40.032368},
#   'code': 'DDG',
#   'name_translations': {'en': 'Langtou Airport'},
#   'country_code': 'CN',
#   'city_code': 'DDG'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Вэйхай',
#   'flightable': True,
#   'coordinates': {'lon': 122.23607, 'lat': 37.18814},
#   'code': 'WEH',
#   'name_translations': {'en': 'Weihai International Airport'},
#   'country_code': 'CN',
#   'city_code': 'WEH'},
#  {'time_zone': 'Asia/Dubai',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 54.65, 'lat': 24.433332},
#   'code': 'DHF',
#   'name_translations': {'en': 'Al Dhafra Military Airport'},
#   'country_code': 'AE',
#   'city_code': 'AUH'},
#  {'time_zone': 'Europe/Prague',
#   'name': 'Карловы Вары (автовокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 12.8712765, 'lat': 50.2322052},
#   'code': 'ZIK',
#   'name_translations': {'en': 'Karlovy Vary Bus Station'},
#   'country_code': 'CZ',
#   'city_code': 'KLV'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Наньнин',
#   'flightable': True,
#   'coordinates': {'lon': 108.1675, 'lat': 22.61321},
#   'code': 'NNG',
#   'name_translations': {'en': 'Nanning Airport'},
#   'country_code': 'CN',
#   'city_code': 'NNG'},
#  {'time_zone': 'Asia/Manila',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 120.95, 'lat': 14.6},
#   'code': 'SGL',
#   'name_translations': {'en': 'Sangley Point NAS'},
#   'country_code': 'PH',
#   'city_code': 'MNL'},
#  {'time_zone': 'America/Los_Angeles',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': -118.2436849, 'lat': 34.0522342},
#   'code': 'QLO',
#   'name_translations': {'en': 'Los Angeles Ferry Port'},
#   'country_code': 'US',
#   'city_code': 'LAX'},
#  {'time_zone': 'Europe/Madrid',
#   'name': 'Мадрид (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': -3.7003454, 'lat': 40.4166909},
#   'code': 'XTI',
#   'name_translations': {'en': 'Chamartin Railway St.'},
#   'country_code': 'ES',
#   'city_code': 'MAD'},
#  {'time_zone': 'Australia/Melbourne',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 144.9629796, 'lat': -37.8131869},
#   'code': 'XOM',
#   'name_translations': {'en': 'Melbourne Ferry Port'},
#   'country_code': 'AU',
#   'city_code': 'MEL'},
#  {'time_zone': 'Asia/Ashgabat',
#   'name': 'Ашхабад',
#   'flightable': True,
#   'coordinates': {'lon': 58.366978, 'lat': 37.984184},
#   'code': 'ASB',
#   'name_translations': {'en': 'Ashgabat Airport'},
#   'country_code': 'TM',
#   'city_code': 'ASB'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Ибараки',
#   'flightable': True,
#   'coordinates': {'lon': 140.41472, 'lat': 36.181667},
#   'code': 'IBR',
#   'name_translations': {'en': 'Ibaraki Airport'},
#   'country_code': 'JP',
#   'city_code': 'IBR'},
#  {'time_zone': 'America/New_York',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': -80.166664, 'lat': 25.75},
#   'code': 'MPB',
#   'name_translations': {'en': 'Miami Sea Plane Base'},
#   'country_code': 'US',
#   'city_code': 'MIA'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Циньхуандао',
#   'flightable': False,
#   'coordinates': {'lon': 119.71656, 'lat': 39.965214},
#   'code': 'SHP',
#   'name_translations': {'en': 'Qinhuangdao'},
#   'country_code': 'CN',
#   'city_code': 'SHP'},
#  {'time_zone': 'Europe/Prague',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 14.4204598, 'lat': 50.0878114},
#   'code': 'VOD',
#   'name_translations': {'en': 'Vodochody'},
#   'country_code': 'CZ',
#   'city_code': 'PRG'},
#  {'time_zone': 'Australia/Melbourne',
#   'name': 'Авалон',
#   'flightable': True,
#   'coordinates': {'lon': 144.47308, 'lat': -38.02637},
#   'code': 'AVV',
#   'name_translations': {'en': 'Avalon Airport'},
#   'country_code': 'AU',
#   'city_code': 'MEL'},
#  {'time_zone': 'Asia/Ho_Chi_Minh',
#   'name': 'Дананг',
#   'flightable': True,
#   'coordinates': {'lon': 108.20298, 'lat': 16.055399},
#   'code': 'DAD',
#   'name_translations': {'en': 'Da Nang International Airport'},
#   'country_code': 'VN',
#   'city_code': 'DAD'},
#  {'time_zone': 'Asia/Yerevan',
#   'name': 'Звартноц',
#   'flightable': True,
#   'coordinates': {'lon': 44.39805, 'lat': 40.15272},
#   'code': 'EVN',
#   'name_translations': {'en': 'Zvartnots International Airport'},
#   'country_code': 'AM',
#   'city_code': 'EVN'},
#  {'time_zone': 'Europe/Zurich',
#   'name': 'Цюрих (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 8.5500025, 'lat': 47.367347},
#   'code': 'ZLQ',
#   'name_translations': {'en': 'Oerlikon Railway Station'},
#   'country_code': 'CH',
#   'city_code': 'ZRH'},
#  {'time_zone': 'Europe/Zurich',
#   'name': 'Цюрих (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 8.5500025, 'lat': 47.367347},
#   'code': 'ZLP',
#   'name_translations': {'en': 'HB Railway Station'},
#   'country_code': 'CH',
#   'city_code': 'ZRH'},
#  {'time_zone': 'America/New_York',
#   'name': 'Ньюарк Либерти',
#   'flightable': True,
#   'coordinates': {'lon': -74.17876, 'lat': 40.68907},
#   'code': 'EWR',
#   'name_translations': {'en': 'Newark Liberty International Airport'},
#   'country_code': 'US',
#   'city_code': 'NYC'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Шаньтоу',
#   'flightable': True,
#   'coordinates': {'lon': 116.75859, 'lat': 23.430237},
#   'code': 'SWA',
#   'name_translations': {'en': 'Jieyang Chaoshan Airport'},
#   'country_code': 'CN',
#   'city_code': 'SWA'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Хиросима',
#   'flightable': True,
#   'coordinates': {'lon': 132.91945, 'lat': 34.43611},
#   'code': 'HIJ',
#   'name_translations': {'en': 'Hiroshima Airport'},
#   'country_code': 'JP',
#   'city_code': 'HIJ'},
#  {'time_zone': 'Asia/Taipei',
#   'name': 'Сун-Шан',
#   'flightable': True,
#   'coordinates': {'lon': 121.551926, 'lat': 25.06279},
#   'code': 'TSA',
#   'name_translations': {'en': 'Taipei Songshan Airport'},
#   'country_code': 'TW',
#   'city_code': 'TPE'},
#  {'time_zone': 'America/Havana',
#   'name': 'Хосе Марти',
#   'flightable': True,
#   'coordinates': {'lon': -82.40818, 'lat': 22.99845},
#   'code': 'HAV',
#   'name_translations': {'en': 'Jose Marti International Airport'},
#   'country_code': 'CU',
#   'city_code': 'HAV'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Тяньцзинь (автовокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 117.200983, 'lat': 39.084158},
#   'code': 'TJJ',
#   'name_translations': {'en': 'Tianjin Bus Station'},
#   'country_code': 'CN',
#   'city_code': 'TSN'},
#  {'time_zone': 'Asia/Samarkand',
#   'name': 'Бухара',
#   'flightable': True,
#   'coordinates': {'lon': 64.47479, 'lat': 39.76037},
#   'code': 'BHK',
#   'name_translations': {'en': 'Bukhara Airport'},
#   'country_code': 'UZ',
#   'city_code': 'BHK'},
#  {'time_zone': 'Asia/Bishkek',
#   'name': 'Манас',
#   'flightable': True,
#   'coordinates': {'lon': 74.46945, 'lat': 43.05358},
#   'code': 'FRU',
#   'name_translations': {'en': 'Manas International Airport'},
#   'country_code': 'KG',
#   'city_code': 'FRU'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Байюн',
#   'flightable': True,
#   'coordinates': {'lon': 113.29734, 'lat': 23.387861},
#   'code': 'CAN',
#   'name_translations': {'en': 'Guangzhou Baiyun International Airport'},
#   'country_code': 'CN',
#   'city_code': 'CAN'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Линьи',
#   'flightable': True,
#   'coordinates': {'lon': 118.40707, 'lat': 35.047478},
#   'code': 'LYI',
#   'name_translations': {'en': 'Linyi Airport'},
#   'country_code': 'CN',
#   'city_code': 'LYI'},
#  {'time_zone': 'Africa/Johannesburg',
#   'name': 'Тамбо',
#   'flightable': True,
#   'coordinates': {'lon': 28.231314, 'lat': -26.132664},
#   'code': 'JNB',
#   'name_translations': {'en': 'O.R. Tambo International Airport'},
#   'country_code': 'ZA',
#   'city_code': 'JNB'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Уси',
#   'flightable': True,
#   'coordinates': {'lon': 120.42438, 'lat': 31.49289},
#   'code': 'WUX',
#   'name_translations': {'en': 'Sunan Shuofang International Airport'},
#   'country_code': 'CN',
#   'city_code': 'WUX'},
#  {'time_zone': 'Asia/Pyongyang',
#   'name': 'Санан',
#   'flightable': True,
#   'coordinates': {'lon': 125.666664, 'lat': 39.2},
#   'code': 'FNJ',
#   'name_translations': {'en': 'Pyongyang Sunan International Airport'},
#   'country_code': 'KP',
#   'city_code': 'FNJ'},
#  {'time_zone': 'America/Vancouver',
#   'name': 'Ванкувер (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': -123.1139268, 'lat': 49.261226},
#   'code': 'XEA',
#   'name_translations': {'en': 'Vancouver Railway.'},
#   'country_code': 'CA',
#   'city_code': 'YVR'},
#  {'time_zone': 'Australia/Adelaide',
#   'name': 'Аделаида (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 138.5999594, 'lat': -34.9286212},
#   'code': 'XHX',
#   'name_translations': {'en': 'Adelaide Keswick Railway'},
#   'country_code': 'AU',
#   'city_code': 'ADL'},
#  {'time_zone': 'Asia/Kuching',
#   'name': 'Кота-Кинабалу',
#   'flightable': True,
#   'coordinates': {'lon': 116.05075, 'lat': 5.923961},
#   'code': 'BKI',
#   'name_translations': {'en': 'Kota Kinabalu International Airport'},
#   'country_code': 'MY',
#   'city_code': 'BKI'},
#  {'time_zone': 'Asia/Seoul',
#   'name': 'Муан',
#   'flightable': True,
#   'coordinates': {'lon': 126.38281, 'lat': 34.991405},
#   'code': 'MWX',
#   'name_translations': {'en': 'Muan International Airport'},
#   'country_code': 'KR',
#   'city_code': 'MWX'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Яньцзи',
#   'flightable': True,
#   'coordinates': {'lon': 129.43936, 'lat': 42.885662},
#   'code': 'YNJ',
#   'name_translations': {'en': 'Yanji Chaoyangchuan Airport'},
#   'country_code': 'CN',
#   'city_code': 'YNJ'},
#  {'time_zone': 'Europe/Rome',
#   'name': 'Римини',
#   'flightable': True,
#   'coordinates': {'lon': 12.619594, 'lat': 44.022953},
#   'code': 'RMI',
#   'name_translations': {'en': 'Miramare Airport'},
#   'country_code': 'IT',
#   'city_code': 'RMI'},
#  {'time_zone': 'Asia/Kuala_Lumpur',
#   'name': 'Пенанг',
#   'flightable': True,
#   'coordinates': {'lon': 100.265175, 'lat': 5.292961},
#   'code': 'PEN',
#   'name_translations': {'en': 'Penang International Airport'},
#   'country_code': 'MY',
#   'city_code': 'PEN'},
#  {'time_zone': 'Europe/Berlin',
#   'name': 'Франкфурт-на-Майне (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 8.683333, 'lat': 50.05},
#   'code': 'QGV',
#   'name_translations': {'en': 'Neu Isenburg'},
#   'country_code': 'DE',
#   'city_code': 'FRA'},
#  {'time_zone': 'Europe/Vienna',
#   'name': 'Вена (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 16.3738189, 'lat': 48.2081743},
#   'code': 'XWC',
#   'name_translations': {'en': 'Vienna Central Station'},
#   'country_code': 'AT',
#   'city_code': 'VIE'},
#  {'time_zone': 'Europe/Madrid',
#   'name': 'Барселона (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 2.154007, 'lat': 41.390205},
#   'code': 'YJB',
#   'name_translations': {'en': 'Sants Railway Station'},
#   'country_code': 'ES',
#   'city_code': 'BCN'},
#  {'time_zone': 'Europe/Rome',
#   'name': 'Венеция (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 12.3387844, 'lat': 45.4343363},
#   'code': 'XVY',
#   'name_translations': {'en': 'Mestre Railway.'},
#   'country_code': 'IT',
#   'city_code': 'VCE'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Хуайань',
#   'flightable': True,
#   'coordinates': {'lon': 119.12778, 'lat': 33.7875},
#   'code': 'HIA',
#   'name_translations': {'en': "Huai'an Lianshui Airport"},
#   'country_code': 'CN',
#   'city_code': 'HIA'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Лхаса',
#   'flightable': True,
#   'coordinates': {'lon': 90.90051, 'lat': 29.29305},
#   'code': 'LXA',
#   'name_translations': {'en': 'Lhasa Gonggar Airport'},
#   'country_code': 'CN',
#   'city_code': 'LXA'},
#  {'time_zone': 'Asia/Kolkata',
#   'name': 'Индустан',
#   'flightable': True,
#   'coordinates': {'lon': 77.70556, 'lat': 13.198889},
#   'code': 'BLR',
#   'name_translations': {'en': 'Kempegowda International Airport'},
#   'country_code': 'IN',
#   'city_code': 'BLR'},
#  {'time_zone': 'Asia/Ho_Chi_Minh',
#   'name': 'Нойбей',
#   'flightable': True,
#   'coordinates': {'lon': 105.802826, 'lat': 21.214184},
#   'code': 'HAN',
#   'name_translations': {'en': 'Noi Bai International Airport'},
#   'country_code': 'VN',
#   'city_code': 'HAN'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Ибинь',
#   'flightable': True,
#   'coordinates': {'lon': 104.54395, 'lat': 28.797659},
#   'code': 'YBP',
#   'name_translations': {'en': 'Yibin Caiba Airport'},
#   'country_code': 'CN',
#   'city_code': 'YBP'},
#  {'time_zone': 'Europe/Madrid',
#   'name': 'Валенсия (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': -0.4558824, 'lat': 39.4907322},
#   'code': 'YJV',
#   'name_translations': {'en': 'Valencia Railway Station'},
#   'country_code': 'ES',
#   'city_code': 'VLC'},
#  {'time_zone': 'Europe/Berlin',
#   'name': 'Штутгарт',
#   'flightable': True,
#   'coordinates': {'lon': 9.193624, 'lat': 48.69073},
#   'code': 'STR',
#   'name_translations': {'en': 'Stuttgart Airport'},
#   'country_code': 'DE',
#   'city_code': 'STR'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Луси',
#   'flightable': True,
#   'coordinates': {'lon': 98.5319, 'lat': 24.40528},
#   'code': 'LUM',
#   'name_translations': {'en': 'Dehong Mangshi Airport'},
#   'country_code': 'CN',
#   'city_code': 'LUM'},
#  {'time_zone': 'Europe/Athens',
#   'name': 'Элефтериос Веницелос',
#   'flightable': True,
#   'coordinates': {'lon': 23.946486, 'lat': 37.93635},
#   'code': 'ATH',
#   'name_translations': {'en': 'Eleftherios Venizelos International Airport'},
#   'country_code': 'GR',
#   'city_code': 'ATH'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Такамацу',
#   'flightable': True,
#   'coordinates': {'lon': 134.01825, 'lat': 34.219017},
#   'code': 'TAK',
#   'name_translations': {'en': 'Takamatsu Airport'},
#   'country_code': 'JP',
#   'city_code': 'TAK'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Хайкоу',
#   'flightable': True,
#   'coordinates': {'lon': 110.45717, 'lat': 19.941612},
#   'code': 'HAK',
#   'name_translations': {'en': 'Haikou Airport'},
#   'country_code': 'CN',
#   'city_code': 'HAK'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Тояма',
#   'flightable': True,
#   'coordinates': {'lon': 137.18945, 'lat': 36.64245},
#   'code': 'TOY',
#   'name_translations': {'en': 'Toyama Airport'},
#   'country_code': 'JP',
#   'city_code': 'TOY'},
#  {'time_zone': 'Europe/Berlin',
#   'name': 'Тегель',
#   'flightable': True,
#   'coordinates': {'lon': 13.291722, 'lat': 52.553944},
#   'code': 'TXL',
#   'name_translations': {'en': 'Tegel Airport'},
#   'country_code': 'DE',
#   'city_code': 'BER'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Хэфэй',
#   'flightable': True,
#   'coordinates': {'lon': 117.28333, 'lat': 31.85},
#   'code': 'HFE',
#   'name_translations': {'en': 'Hefei Xinqiao Airport'},
#   'country_code': 'CN',
#   'city_code': 'HFE'},
#  {'time_zone': 'Asia/Riyadh',
#   'name': 'Кинг Халид',
#   'flightable': True,
#   'coordinates': {'lon': 46.702877, 'lat': 24.95929},
#   'code': 'RUH',
#   'name_translations': {'en': 'King Khaled International Airport'},
#   'country_code': 'SA',
#   'city_code': 'RUH'},
#  {'time_zone': 'Asia/Hong_Kong',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 114.2, 'lat': 22.318056},
#   'code': 'HHP',
#   'name_translations': {'en': 'H K Heliport'},
#   'country_code': 'HK',
#   'city_code': 'HKG'},
#  {'time_zone': 'Europe/Istanbul',
#   'name': 'Анталья',
#   'flightable': True,
#   'coordinates': {'lon': 30.80135, 'lat': 36.89928},
#   'code': 'AYT',
#   'name_translations': {'en': 'Antalya Airport'},
#   'country_code': 'TR',
#   'city_code': 'AYT'},
#  {'time_zone': 'Pacific/Honolulu',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': -157.86667, 'lat': 21.316668},
#   'code': 'HIK',
#   'name_translations': {'en': 'Hickam AFB'},
#   'country_code': 'US',
#   'city_code': 'HNL'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Цюаньчжоу',
#   'flightable': True,
#   'coordinates': {'lon': 118.587296, 'lat': 24.802809},
#   'code': 'JJN',
#   'name_translations': {'en': 'Quanzhou Jinjiang International Airport'},
#   'country_code': 'CN',
#   'city_code': 'JJN'},
#  {'time_zone': 'Europe/Oslo',
#   'name': 'Торп',
#   'flightable': True,
#   'coordinates': {'lon': 10.251807, 'lat': 59.178085},
#   'code': 'TRF',
#   'name_translations': {'en': 'Torp Sandefjord Airport'},
#   'country_code': 'NO',
#   'city_code': 'OSL'},
#  {'time_zone': 'Europe/Madrid',
#   'name': 'Аликанте',
#   'flightable': True,
#   'coordinates': {'lon': -0.557381, 'lat': 38.287098},
#   'code': 'ALC',
#   'name_translations': {'en': 'Alicante-Elche Airport'},
#   'country_code': 'ES',
#   'city_code': 'ALC'},
#  {'time_zone': 'Europe/Riga',
#   'name': 'Рига',
#   'flightable': True,
#   'coordinates': {'lon': 23.979807, 'lat': 56.92208},
#   'code': 'RIX',
#   'name_translations': {'en': 'Riga International Airport'},
#   'country_code': 'LV',
#   'city_code': 'RIX'},
#  {'time_zone': 'Europe/Rome',
#   'name': 'Мальпенса',
#   'flightable': True,
#   'coordinates': {'lon': 8.71237, 'lat': 45.627403},
#   'code': 'MXP',
#   'name_translations': {'en': 'Milano Malpensa Airport'},
#   'country_code': 'IT',
#   'city_code': 'MIL'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Дацин',
#   'flightable': True,
#   'coordinates': {'lon': 125.22841, 'lat': 46.58736},
#   'code': 'DQA',
#   'name_translations': {'en': 'Daqing Shi Airport'},
#   'country_code': 'CN',
#   'city_code': 'DQA'},
#  {'time_zone': 'Asia/Almaty',
#   'name': 'Астана',
#   'flightable': True,
#   'coordinates': {'lon': 71.4612, 'lat': 51.02781},
#   'code': 'TSE',
#   'name_translations': {'en': 'Astana International Airport'},
#   'country_code': 'KZ',
#   'city_code': 'TSE'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Ичан',
#   'flightable': True,
#   'coordinates': {'lon': 111.478935, 'lat': 30.549934},
#   'code': 'YIH',
#   'name_translations': {'en': 'Yichang Sanxia Airport'},
#   'country_code': 'CN',
#   'city_code': 'YIH'},
#  {'time_zone': 'Asia/Taipei',
#   'name': 'Таоюань',
#   'flightable': True,
#   'coordinates': {'lon': 121.22389, 'lat': 25.07639},
#   'code': 'TPE',
#   'name_translations': {'en': 'Taiwan Taoyuan International Airport'},
#   'country_code': 'TW',
#   'city_code': 'TPE'},
#  {'time_zone': 'America/Chicago',
#   'name': 'Джордж Буш',
#   'flightable': True,
#   'coordinates': {'lon': -95.34, 'lat': 29.983334},
#   'code': 'IAH',
#   'name_translations': {'en': 'George Bush Intercontinental Airport'},
#   'country_code': 'US',
#   'city_code': 'HOU'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Синъи',
#   'flightable': True,
#   'coordinates': {'lon': 104.95944, 'lat': 25.085556},
#   'code': 'ACX',
#   'name_translations': {'en': 'Xingyi Airport'},
#   'country_code': 'CN',
#   'city_code': 'ACX'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Окаяма',
#   'flightable': True,
#   'coordinates': {'lon': 133.85277, 'lat': 34.76022},
#   'code': 'OKJ',
#   'name_translations': {'en': 'Okayama Airport'},
#   'country_code': 'JP',
#   'city_code': 'OKJ'},
#  {'time_zone': 'Africa/Cairo',
#   'name': 'Офира',
#   'flightable': True,
#   'coordinates': {'lon': 34.385254, 'lat': 27.979357},
#   'code': 'SSH',
#   'name_translations': {'en': 'Sharm El Sheikh Airport'},
#   'country_code': 'EG',
#   'city_code': 'SSH'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Бэйхай',
#   'flightable': True,
#   'coordinates': {'lon': 109.28785, 'lat': 21.540333},
#   'code': 'BHY',
#   'name_translations': {'en': 'Beihai Fucheng Airport'},
#   'country_code': 'CN',
#   'city_code': 'BHY'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Сянфань',
#   'flightable': True,
#   'coordinates': {'lon': 112.28627, 'lat': 32.151558},
#   'code': 'XFN',
#   'name_translations': {'en': 'Xiangyang Airport'},
#   'country_code': 'CN',
#   'city_code': 'XFN'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Сидзуока',
#   'flightable': True,
#   'coordinates': {'lon': 138.18944, 'lat': 34.796112},
#   'code': 'FSZ',
#   'name_translations': {'en': 'Shizuoka Airport'},
#   'country_code': 'JP',
#   'city_code': 'FSZ'},
#  {'time_zone': 'Asia/Manila',
#   'name': 'Себу-Мактан',
#   'flightable': True,
#   'coordinates': {'lon': 123.98278, 'lat': 10.313333},
#   'code': 'CEB',
#   'name_translations': {'en': 'Mactan-Cebu International Airport'},
#   'country_code': 'PH',
#   'city_code': 'CEB'},
#  {'time_zone': 'Europe/Prague',
#   'name': 'Прага (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 14.4204598, 'lat': 50.0878114},
#   'code': 'XYG',
#   'name_translations': {'en': 'Prague Main Railway Station'},
#   'country_code': 'CZ',
#   'city_code': 'PRG'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Сага',
#   'flightable': True,
#   'coordinates': {'lon': 130.30278, 'lat': 33.153828},
#   'code': 'HSG',
#   'name_translations': {'en': 'Saga Airport'},
#   'country_code': 'JP',
#   'city_code': 'HSG'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Асахикава',
#   'flightable': True,
#   'coordinates': {'lon': 142.45454, 'lat': 43.67109},
#   'code': 'AKJ',
#   'name_translations': {'en': 'Asahikawa Airport'},
#   'country_code': 'JP',
#   'city_code': 'AKJ'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Баган',
#   'flightable': True,
#   'coordinates': {'lon': 96.0, 'lat': 24.0},
#   'code': 'BPE',
#   'name_translations': {'en': 'Qinhuangdao Beidaihe Airport'},
#   'country_code': 'CN',
#   'city_code': 'SHP'},
#  {'time_zone': 'Asia/Manila',
#   'name': 'Кларк',
#   'flightable': True,
#   'coordinates': {'lon': 120.546486, 'lat': 15.182571},
#   'code': 'CRK',
#   'name_translations': {'en': 'Diosdado Macapagal International (Clark International)'},
#   'country_code': 'PH',
#   'city_code': 'CRK'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Чжухай (автовокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 113.576726, 'lat': 22.270715},
#   'code': 'ZIU',
#   'name_translations': {'en': 'Railway'},
#   'country_code': 'CN',
#   'city_code': 'ZUH'},
#  {'time_zone': 'America/Los_Angeles',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': -118.25, 'lat': 34.066666},
#   'code': 'JSN',
#   'name_translations': {'en': 'Sherman Oaks Heliport'},
#   'country_code': 'US',
#   'city_code': 'LAX'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Тунси',
#   'flightable': True,
#   'coordinates': {'lon': 118.25646, 'lat': 29.72962},
#   'code': 'TXN',
#   'name_translations': {'en': 'Huangshan Tunxi International Airport'},
#   'country_code': 'CN',
#   'city_code': 'TXN'},
#  {'time_zone': 'Asia/Seoul',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 126.566666, 'lat': 33.483334},
#   'code': 'JSP',
#   'name_translations': {'en': 'Seogwipo Heliport'},
#   'country_code': 'KR',
#   'city_code': 'CJU'},
#  {'time_zone': 'America/Los_Angeles',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': -118.26667, 'lat': 34.083332},
#   'code': 'JUC',
#   'name_translations': {'en': 'Universal City Heliport'},
#   'country_code': 'US',
#   'city_code': 'LAX'},
#  {'time_zone': 'Asia/Almaty',
#   'name': 'Алматы',
#   'flightable': True,
#   'coordinates': {'lon': 77.01145, 'lat': 43.346653},
#   'code': 'ALA',
#   'name_translations': {'en': 'Almaty Airport'},
#   'country_code': 'KZ',
#   'city_code': 'ALA'},
#  {'time_zone': 'Asia/Bangkok',
#   'name': 'Пхукет',
#   'flightable': True,
#   'coordinates': {'lon': 98.306435, 'lat': 8.107619},
#   'code': 'HKT',
#   'name_translations': {'en': 'Phuket International Airport'},
#   'country_code': 'TH',
#   'city_code': 'HKT'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Джиу-Жай Хуанглонг',
#   'flightable': True,
#   'coordinates': {'lon': 103.68306, 'lat': 32.856667},
#   'code': 'JZH',
#   'name_translations': {'en': 'Jiuzhai Huanglong Airport'},
#   'country_code': 'CN',
#   'city_code': 'JZH'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Чжэнчжоу',
#   'flightable': True,
#   'coordinates': {'lon': 113.84024, 'lat': 34.52752},
#   'code': 'CGO',
#   'name_translations': {'en': 'Zhengzhou Xinzheng Airport'},
#   'country_code': 'CN',
#   'city_code': 'CGO'},
#  {'time_zone': 'Europe/Kiev',
#   'name': 'Борисполь',
#   'flightable': True,
#   'coordinates': {'lon': 30.895206, 'lat': 50.341244},
#   'code': 'KBP',
#   'name_translations': {'en': 'Boryspil International Airport'},
#   'country_code': 'UA',
#   'city_code': 'IEV'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Чунцин',
#   'flightable': True,
#   'coordinates': {'lon': 106.63408, 'lat': 29.72034},
#   'code': 'CKG',
#   'name_translations': {'en': 'Chongqing Jiangbei International Airport'},
#   'country_code': 'CN',
#   'city_code': 'CKG'},
#  {'time_zone': 'Europe/Rome',
#   'name': 'Болонья (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 11.3465185, 'lat': 44.4941903},
#   'code': 'IBT',
#   'name_translations': {'en': 'Bologna Central Railway Station'},
# ...
#   'flightable': True,
#   'coordinates': {'lon': 120.43236, 'lat': 30.236935},
#   'code': 'HGH',
#   'name_translations': {'en': 'Hangzhou Xiaoshan International Airport'},
#   'country_code': 'CN',
#   'city_code': 'HGH'},
#  {'time_zone': 'Europe/Istanbul',
#   'name': 'Стамбул Новый аэропорт',
#   'flightable': True,
#   'coordinates': {'lon': 28.82055, 'lat': 40.9769},
#   'code': 'IST',
#   'name_translations': {'en': 'Istanbul New Airport'},
#   'country_code': 'TR',
#   'city_code': 'IST'},
#  {'time_zone': 'Asia/Ulaanbaatar',
#   'name': 'Улан-Батор',
#   'flightable': True,
#   'coordinates': {'lon': 106.76327, 'lat': 47.85275},
#   'code': 'ULN',
#   'name_translations': {'en': 'Chinggis Khaan International Airport'},
#   'country_code': 'MN',
#   'city_code': 'ULN'},
#  {'time_zone': 'Asia/Hong_Kong',
#   'name': 'Гонконг ',
#   'flightable': True,
#   'coordinates': {'lon': 113.93649, 'lat': 22.315248},
#   'code': 'HKG',
#   'name_translations': {'en': 'Hong Kong International Airport'},
#   'country_code': 'HK',
#   'city_code': 'HKG'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Улан-Хото',
#   'flightable': True,
#   'coordinates': {'lon': 122.00148, 'lat': 46.19349},
#   'code': 'HLH',
#   'name_translations': {'en': 'Ulanhot Airport'},
#   'country_code': 'CN',
#   'city_code': 'HLH'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Хами',
#   'flightable': True,
#   'coordinates': {'lon': 93.416664, 'lat': 42.916668},
#   'code': 'HMI',
#   'name_translations': {'en': 'Hami Airport'},
#   'country_code': 'CN',
#   'city_code': 'HMI'},
#  {'time_zone': 'Asia/Singapore',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 103.96667, 'lat': 1.366667},
#   'code': 'XSP',
#   'name_translations': {'en': 'Seletar'},
#   'country_code': 'SG',
#   'city_code': 'SIN'},
#  {'time_zone': 'Europe/Zaporozhye',
#   'name': 'Запорожье',
#   'flightable': True,
#   'coordinates': {'lon': 35.315834, 'lat': 47.8675},
#   'code': 'OZH',
#   'name_translations': {'en': 'Zaporozhye Airport'},
#   'country_code': 'UA',
#   'city_code': 'OZH'},
#  {'time_zone': 'America/New_York',
#   'name': None,
#   'flightable': False,
#   'coordinates': None,
#   'code': 'ZRP',
#   'name_translations': {'en': 'Pennsylvania Railroad Station'},
#   'country_code': 'US',
#   'city_code': 'EWR'},
#  {'time_zone': 'Asia/Seoul',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 126.32778, 'lat': 33.944443},
#   'code': 'JCJ',
#   'name_translations': {'en': 'Chuja Heliport'},
#   'country_code': 'KR',
#   'city_code': 'CJU'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Цзиндэчжень',
#   'flightable': True,
#   'coordinates': {'lon': 117.17879, 'lat': 29.33549},
#   'code': 'JDZ',
#   'name_translations': {'en': 'Jingdezhen Airport'},
#   'country_code': 'CN',
#   'city_code': 'JDZ'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Гаса',
#   'flightable': True,
#   'coordinates': {'lon': 100.76646, 'lat': 21.973421},
#   'code': 'JHG',
#   'name_translations': {'en': 'Xishuangbanna Gasa Airport'},
#   'country_code': 'CN',
#   'city_code': 'JHG'},
#  {'time_zone': 'Asia/Singapore',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 103.9, 'lat': 1.35},
#   'code': 'QPG',
#   'name_translations': {'en': 'Paya Lebar'},
#   'country_code': 'SG',
#   'city_code': 'SIN'},
#  {'time_zone': 'America/Los_Angeles',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': -118.333336, 'lat': 34.166668},
#   'code': 'JLX',
#   'name_translations': {'en': 'Union Station Heliport'},
#   'country_code': 'US',
#   'city_code': 'LAX'},
#  {'time_zone': 'Europe/Sofia',
#   'name': 'Варна',
#   'flightable': True,
#   'coordinates': {'lon': 27.829096, 'lat': 43.23726},
#   'code': 'VAR',
#   'name_translations': {'en': 'Varna Airport'},
#   'country_code': 'BG',
#   'city_code': 'VAR'},
#  {'time_zone': 'America/Los_Angeles',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': -118.25, 'lat': 34.066666},
#   'code': 'JWC',
#   'name_translations': {'en': 'Warner Cntr Bus. Plaza'},
#   'country_code': 'US',
#   'city_code': 'LAX'},
#  {'time_zone': 'Asia/Manila',
#   'name': 'Ниной Акино',
#   'flightable': True,
#   'coordinates': {'lon': 121.01251, 'lat': 14.509602},
#   'code': 'MNL',
#   'name_translations': {'en': 'Ninoy Aquino International Airport'},
#   'country_code': 'PH',
#   'city_code': 'MNL'},
#  {'time_zone': 'Europe/Vilnius',
#   'name': 'Вильнюс',
#   'flightable': True,
#   'coordinates': {'lon': 25.279606, 'lat': 54.643078},
#   'code': 'VNO',
#   'name_translations': {'en': 'Vilnius International Airport'},
#   'country_code': 'LT',
#   'city_code': 'VNO'},
#  {'time_zone': 'Asia/Dubai',
#   'name': 'Абу-Даби',
#   'flightable': True,
#   'coordinates': {'lon': 54.645973, 'lat': 24.426912},
#   'code': 'AUH',
#   'name_translations': {'en': 'Abu Dhabi International Airport'},
#   'country_code': 'AE',
#   'city_code': 'AUH'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Кашгар',
#   'flightable': True,
#   'coordinates': {'lon': 76.01107, 'lat': 39.534973},
#   'code': 'KHG',
#   'name_translations': {'en': 'Kashi Airport'},
#   'country_code': 'CN',
#   'city_code': 'KHG'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Кансай',
#   'flightable': True,
#   'coordinates': {'lon': 135.24397, 'lat': 34.43533},
#   'code': 'KIX',
#   'name_translations': {'en': 'Kansai International Airport'},
#   'country_code': 'JP',
#   'city_code': 'OSA'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Наньчан',
#   'flightable': True,
#   'coordinates': {'lon': 115.907845, 'lat': 28.859901},
#   'code': 'KHN',
#   'name_translations': {'en': 'Nanchang Changbei International Airport'},
#   'country_code': 'CN',
#   'city_code': 'KHN'},
#  {'time_zone': 'Asia/Bangkok',
#   'name': 'Дон-Муанг',
#   'flightable': True,
#   'coordinates': {'lon': 100.60667, 'lat': 13.9125},
#   'code': 'DMK',
#   'name_translations': {'en': 'Don Mueang International Airport'},
#   'country_code': 'TH',
#   'city_code': 'BKK'},
#  {'time_zone': 'America/Vancouver',
#   'name': 'Кол-Харбор',
#   'flightable': True,
#   'coordinates': {'lon': -123.11667, 'lat': 49.266666},
#   'code': 'CXH',
#   'name_translations': {'en': 'Coal Harbour Sea Plane Base'},
#   'country_code': 'CA',
#   'city_code': 'YVR'},
#  {'time_zone': 'Europe/Stockholm',
#   'name': 'Гётеборг (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 11.9865, 'lat': 57.6969943},
#   'code': 'XWL',
#   'name_translations': {'en': 'Goteborg C Railway Station'},
#   'country_code': 'SE',
#   'city_code': 'GOT'},
#  {'time_zone': 'Europe/Prague',
#   'name': 'Карловы Вары',
#   'flightable': True,
#   'coordinates': {'lon': 12.916667, 'lat': 50.2},
#   'code': 'KLV',
#   'name_translations': {'en': 'Karlovy Vary Airport'},
#   'country_code': 'CZ',
#   'city_code': 'KLV'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Вуйшань',
#   'flightable': True,
#   'coordinates': {'lon': 117.96667, 'lat': 27.716667},
#   'code': 'WUS',
#   'name_translations': {'en': 'Wuyishan Airport'},
#   'country_code': 'CN',
#   'city_code': 'WUS'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Ганьчжоу',
#   'flightable': True,
#   'coordinates': {'lon': 114.776665, 'lat': 25.851667},
#   'code': 'KOW',
#   'name_translations': {'en': 'Ganzhou Airport'},
#   'country_code': 'CN',
#   'city_code': 'KOW'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Сюйчжоу',
#   'flightable': True,
#   'coordinates': {'lon': 117.55408, 'lat': 34.052925},
#   'code': 'XUZ',
#   'name_translations': {'en': 'Xuzhou Guanyin Airport'},
#   'country_code': 'CN',
#   'city_code': 'XUZ'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Юньчэн',
#   'flightable': True,
#   'coordinates': {'lon': 110.993, 'lat': 35.018},
#   'code': 'YCU',
#   'name_translations': {'en': 'Yuncheng Airport'},
#   'country_code': 'CN',
#   'city_code': 'YCU'},
#  {'time_zone': 'Asia/Samarkand',
#   'name': 'Карши',
#   'flightable': True,
#   'coordinates': {'lon': 65.77531, 'lat': 38.80981},
#   'code': 'KSQ',
#   'name_translations': {'en': 'Karshi Airport'},
#   'country_code': 'UZ',
#   'city_code': 'KSQ'},
#  {'time_zone': 'Asia/Kathmandu',
#   'name': 'Катманду',
#   'flightable': True,
#   'coordinates': {'lon': 85.35657, 'lat': 27.699905},
#   'code': 'KTM',
#   'name_translations': {'en': 'Tribhuvan International Airport'},
#   'country_code': 'NP',
#   'city_code': 'KTM'},
#  {'time_zone': 'Europe/Paris',
#   'name': 'Лион (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 4.835659, 'lat': 45.764043},
#   'code': 'XYL',
#   'name_translations': {'en': 'Lyon Perrache RailwaySvc'},
#   'country_code': 'FR',
#   'city_code': 'LYS'},
#  {'time_zone': 'Europe/Vienna',
#   'name': 'Вена (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 16.3738189, 'lat': 48.2081743},
#   'code': 'XWT',
#   'name_translations': {'en': 'Mitte CAT Rail Station'},
#   'country_code': 'AT',
#   'city_code': 'VIE'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Нарита',
#   'flightable': True,
#   'coordinates': {'lon': 140.38744, 'lat': 35.773212},
#   'code': 'NRT',
#   'name_translations': {'en': 'Narita International Airport'},
#   'country_code': 'JP',
#   'city_code': 'TYO'},
#  {'time_zone': 'Asia/Baku',
#   'name': 'Гянджа',
#   'flightable': True,
#   'coordinates': {'lon': 46.316666, 'lat': 40.733334},
#   'code': 'KVD',
#   'name_translations': {'en': 'Gyandzha Airport'},
#   'country_code': 'AZ',
#   'city_code': 'KVD'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Гуйян',
#   'flightable': True,
#   'coordinates': {'lon': 106.79598, 'lat': 26.544216},
#   'code': 'KWE',
#   'name_translations': {'en': 'Guiyang Longdongbao International Airport'},
#   'country_code': 'CN',
#   'city_code': 'KWE'},
#  {'time_zone': 'America/New_York',
#   'name': None,
#   'flightable': False,
#   'coordinates': None,
#   'code': 'ZME',
#   'name_translations': {'en': 'Metropark Railway'},
#   'country_code': 'US',
#   'city_code': 'EWR'},
#  {'time_zone': 'Asia/Macau',
#   'name': None,
#   'flightable': True,
#   'coordinates': {'lon': 113.5549937, 'lat': 22.1638446},
#   'code': 'XZM',
#   'name_translations': {'en': 'Macau Ferry'},
#   'country_code': 'MO',
#   'city_code': 'MFM'},
#  {'time_zone': 'Asia/Dushanbe',
#   'name': 'Худжанд',
#   'flightable': True,
#   'coordinates': {'lon': 69.6965, 'lat': 40.219887},
#   'code': 'LBD',
#   'name_translations': {'en': 'Khujand Airport'},
#   'country_code': 'TJ',
#   'city_code': 'LBD'},
#  {'time_zone': 'Asia/Tokyo',
#   'name': 'Сендай',
#   'flightable': True,
#   'coordinates': {'lon': 140.92389, 'lat': 38.135555},
#   'code': 'SDJ',
#   'name_translations': {'en': 'Sendai Airport'},
#   'country_code': 'JP',
#   'city_code': 'SDJ'},
#  {'time_zone': 'America/Los_Angeles',
#   'name': 'Такома',
#   'flightable': True,
#   'coordinates': {'lon': -122.301735, 'lat': 47.44384},
#   'code': 'SEA',
#   'name_translations': {'en': 'Seattle-Tacoma International Airport'},
#   'country_code': 'US',
#   'city_code': 'SEA'},
#  {'time_zone': 'Europe/Prague',
#   'name': 'Прага (автовокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 14.4204598, 'lat': 50.0878114},
#   'code': 'PFL',
#   'name_translations': {'en': 'Florenc Bus Station'},
#   'country_code': 'CZ',
#   'city_code': 'PRG'},
#  {'time_zone': 'Europe/Madrid',
#   'name': 'Барселона (автовокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 2.1699187, 'lat': 41.387917},
#   'code': 'XJB',
#   'name_translations': {'en': 'Barcelona Bus Station'},
#   'country_code': 'ES',
#   'city_code': 'BCN'},
#  {'time_zone': 'America/New_York',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': -80.183334, 'lat': 25.783333},
#   'code': 'TNT',
#   'name_translations': {'en': 'Dade Collier'},
#   'country_code': 'US',
#   'city_code': 'MIA'},
#  {'time_zone': 'Europe/Kiev',
#   'name': 'Сергей Прокофьев',
#   'flightable': False,
#   'coordinates': {'lon': 37.75, 'lat': 48.083332},
#   'code': 'DOK',
#   'name_translations': {'en': 'Donetsk International Airport'},
#   'country_code': 'UA',
#   'city_code': 'DOK'},
#  {'time_zone': 'Asia/Hong_Kong',
#   'name': None,
#   'flightable': True,
#   'coordinates': {'lon': 114.2033843, 'lat': 22.2478599},
#   'code': 'XJH',
#   'name_translations': {'en': 'Hong Kong Harbour'},
#   'country_code': 'HK',
#   'city_code': 'HKG'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Ланчжоу',
#   'flightable': True,
#   'coordinates': {'lon': 103.86667, 'lat': 36.033333},
#   'code': 'LHW',
#   'name_translations': {'en': 'Lanzhou Zhongchuan International Airport'},
#   'country_code': 'CN',
#   'city_code': 'LHW'},
#  {'time_zone': 'Europe/Madrid',
#   'name': 'Барахас',
#   'flightable': True,
#   'coordinates': {'lon': -3.570209, 'lat': 40.46515},
#   'code': 'MAD',
#   'name_translations': {'en': 'Adolfo Suarez Madrid-Barajas Airport'},
#   'country_code': 'ES',
#   'city_code': 'MAD'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': None,
#   'flightable': True,
#   'coordinates': {'lon': 114.057868, 'lat': 22.543099},
#   'code': 'FYG',
#   'name_translations': {'en': 'Fuyong Ferry Port'},
#   'country_code': 'CN',
#   'city_code': 'SZX'},
#  {'time_zone': 'Australia/Sydney',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 151.03334, 'lat': -33.916668},
#   'code': 'BWU',
#   'name_translations': {'en': 'Sydney Bankstown'},
#   'country_code': 'AU',
#   'city_code': 'SYD'},
#  {'time_zone': 'Asia/Manila',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 121.0, 'lat': 16.0},
#   'code': 'NCP',
#   'name_translations': {'en': 'Cubi Pt NAS'},
#   'country_code': 'PH',
#   'city_code': 'CRK'},
#  {'time_zone': 'America/New_York',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': -80.25, 'lat': 25.75},
#   'code': 'JDM',
#   'name_translations': {'en': 'Miami Downtown Heliport'},
#   'country_code': 'US',
#   'city_code': 'MIA'},
#  {'time_zone': 'America/Los_Angeles',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': -118.15972, 'lat': 33.986668},
#   'code': 'JBP',
#   'name_translations': {'en': 'Commerce Bus. Plaza'},
#   'country_code': 'US',
#   'city_code': 'LAX'},
#  {'time_zone': 'Europe/Berlin',
#   'name': 'Финкенвердер',
#   'flightable': True,
#   'coordinates': {'lon': 9.836945, 'lat': 52.535835},
#   'code': 'XFW',
#   'name_translations': {'en': 'Hamburg Finkenwerder Airport'},
#   'country_code': 'DE',
#   'city_code': 'HAM'},
#  {'time_zone': 'Europe/Lisbon',
#   'name': 'Лиссабон (автовокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 124.28081, 'lat': 40.032368},
#   'code': 'ZYD',
#   'name_translations': {'en': 'Lisbon TP'},
#   'country_code': 'PT',
#   'city_code': 'LIS'},
#  {'time_zone': 'Asia/Dubai',
#   'name': 'Дубай (автовокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 55.3116667, 'lat': 25.2644444},
#   'code': 'ZXZ',
#   'name_translations': {'en': 'Jumeirah Beach Bus Station'},
#   'country_code': 'AE',
#   'city_code': 'DXB'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': 'Цзюцзянь',
#   'flightable': False,
#   'coordinates': {'lon': 115.96667, 'lat': 29.7},
#   'code': 'JIU',
#   'name_translations': {'en': 'Jiujiang'},
#   'country_code': 'CN',
#   'city_code': 'JIU'},
#  {'time_zone': 'Europe/Vienna',
#   'name': 'Вена (жд вокзал)',
#   'flightable': True,
#   'coordinates': {'lon': 16.3738189, 'lat': 48.2081743},
#   'code': 'XWW',
#   'name_translations': {'en': 'Westbahnhof Railway'},
#   'country_code': 'AT',
#   'city_code': 'VIE'},
#  {'time_zone': 'Europe/Helsinki',
#   'name': 'Тиккурила железнодорожная станция',
#   'flightable': False,
#   'coordinates': {'lon': 0.0, 'lat': 0.0},
#   'code': 'HVT',
#   'name_translations': {'en': 'Tikkurila railway station'},
#   'country_code': 'FI',
#   'city_code': 'HEL'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 114.057868, 'lat': 22.543099},
#   'code': 'ZYX',
#   'name_translations': {'en': 'Yantian Ferry Port'},
#   'country_code': 'CN',
#   'city_code': 'SZX'},
#  {'time_zone': 'Europe/Paris',
#   'name': 'Кань-сюр-Мер',
#   'flightable': False,
#   'coordinates': {'lon': 0.0, 'lat': 0.0},
#   'code': 'XCG',
#   'name_translations': {'en': 'Gare de Cagnes-sur-Mer'},
#   'country_code': 'FR',
#   'city_code': 'NCE'},
#  {'time_zone': 'Asia/Shanghai',
#   'name': None,
#   'flightable': True,
#   'coordinates': {'lon': 113.576726, 'lat': 22.270715},
#   'code': 'ZUI',
#   'name_translations': {'en': 'Jiuzhou Ferry Port'},
#   'country_code': 'CN',
#   'city_code': 'ZUH'},
#  {'time_zone': 'Africa/Johannesburg',
#   'name': None,
#   'flightable': False,
#   'coordinates': {'lon': 28.15, 'lat': -26.233334},
#   'code': 'GCJ',
#   'name_translations': {'en': 'Grand Central'},
#   'country_code': 'ZA',
#   'city_code': 'JNB'}]

# %%
def list_dates(datetime_start, datetime_end):
    delta = timedelta(days = 1)
    range_dates = []
    date = datetime_start
    while date <= datetime_end:
        range_dates.append(date)
        date = date + delta   
    return range_dates

def open_json(path):
    try:
        with open(path, encoding='utf-8', mode = 'r') as file:
            json_base = json.load(file)
    except FileNotFoundError:
        json_base = []
    return json_base

def write_json(path, json_base):
    with open(path, encoding='utf-8', mode = 'w') as file:
        json.dump(json_base, file)

# %%
def get_destinations(routes, origin):
    destination_list = list(filter(lambda x: x['departure_airport_iata'] == origin, routes))
    destination_list = list(set(map(lambda x: x['arrival_airport_iata'],destination_list)))
    return destination_list

# %%
def update_browser_query(path, days = 5):
    browser_query = open_json(path)
    current_time = datetime.utcnow() - timedelta(days = days)
    browser_query = list(filter(lambda x: datetime.strptime(x['timestamp'], 
                                                            '%Y-%m-%d %H:%M:%S') > current_time, browser_query))  
    write_json(path, browser_query)  

def check_browser_query(date, origin, destination): 
    rewrite = True
    browser_query = open_json('browser_query.json')
    checker = list(filter(lambda x: ((x['date'] == date) & (x['origin'] == origin) & 
                                     (x['destination'] == destination)), browser_query))    
    if len(checker) != 0: rewrite = False          
    return rewrite   

def add_browser_query(date, origin, destination): 
    browser_query = open_json('browser_query.json')
    browser_query.append({'date':date, 'origin':origin, 
         'destination':destination, 'timestamp':datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S')})
    write_json('browser_query.json', browser_query)

# %%
def update_price_base(path, days = 5):
    ticket_base = open_json(path)
    current_time = datetime.utcnow() - timedelta(days = days)   
    ticket_base = list(filter(lambda x: datetime.strptime(x['found_at'], 
                                                            '%Y-%m-%dT%H:%M:%S') > current_time, ticket_base))    
    write_json(path, ticket_base)       

def check_ticket_price(date, origin, destination): 
    rewrite = True
    ticket_base = open_json('ticket_base.json')       
    checker = list(filter(lambda x: ((x['depart_date'] == date) & (x['origin'] == origin) & 
                                     (x['destination'] == destination)), ticket_base))    
    if len(checker) != 0: rewrite = False       
    return rewrite

def get_ticket_price(date, origin, destination):
    ticket_base = open_json('ticket_base.json')
    ticket = list(filter(lambda x: ((x['depart_date'] == date) & (x['origin'] == origin) & 
                                     (x['destination'] == destination)), ticket_base))
    return ticket

def add_ticket_price(date, origin, destination, ticket): 
    ticket_base = open_json('ticket_base.json')
    ticket_base = ticket_base + ticket
    write_json('ticket_base.json', ticket_base)

# %%
def get_price_routes(datetime_start, datetime_end, required_routes):
    tickets = []
    update_price_base('ticket_base.json')
    update_browser_query('browser_query.json')
    
    parameters = list(product(required_routes, list_dates(datetime_start, datetime_end)))

    for route, datetime_object in tqdm(parameters, total=len(parameters), desc='send_query'):
        month, day = add_zero(datetime_object.month), add_zero(datetime_object.day)
        date = datetime_object.strftime('%Y-%m-%d')
        for chain in route:
            origin, destination = chain

            url_for_cash = f'https://www.aviasales.ru/search/{origin}{day}{month}{destination}1'
        
            if check_browser_query(date, origin, destination):
                driver.get(url_for_cash)
                sleep(time_sleep)
                while "Извините, доступ к поиску" in driver.page_source:
                    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S'), 'sleeping 20 minutes')
                    sleep(1200)
                    driver.get(url_for_cash)

                add_browser_query(date, origin, destination)
                
    
    for route, datetime_object in tqdm(parameters, total=len(parameters), desc='get_price_from'):      
        date = datetime_object.strftime('%Y-%m-%d')
        for chain in route:
            origin, destination = chain
        
            if check_ticket_price(date, origin, destination):
                params = {'currency': 'rub', 'show_to_affiliates':'false', 'token' : ACCESS_TOKEN, 'one_way':'true',
                        'origin': origin, 'destination': destination, 'month':date}
                response = requests.get(url, params=params)
                if 'errors' not in json.loads(response.text)['data']:
                    ticket = json.loads(response.text)['data']
                    add_ticket_price(date, origin, destination, ticket)
                    tickets = tickets + ticket  
            else:
                tickets = tickets + get_ticket_price(date, origin, destination)    
    return tickets

# %%
from math import radians, cos, sin, asin, sqrt
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    # Radius of earth in kilometers is 6371
    km = 6371* c
    return km


def distance(rout, data):
    lon1, lat1 = tuple(list(filter(lambda x: (x['city_code'] == rout[0]) 
                               or (x['code'] == rout[0]), data))[0]['coordinates'].values())
    
    lon2, lat2 = tuple(list(filter(lambda x: (x['city_code'] == rout[1]) 
                               or (x['code'] == rout[1]), data))[0]['coordinates'].values())
    
    km = haversine(lon1, lat1, lon2, lat2)
    return km

# %%
# distance = list(map(lambda x: sum(map(lambda y: distance(y, data),x)), required_routes))
# required_routes = [x for _,x in sorted(zip(distance,required_routes))]

# %%
tickets_list = []

datetime_start = datetime.strptime(date_start, '%Y-%m-%d')
datetime_end = datetime.strptime(date_end, '%Y-%m-%d')

#destination_list = get_destinations(routes, origin)

tickets_list.append(get_price_routes(datetime_start, datetime_end, required_routes[:10]))   

# for change in range(number_place):
#     ponts_list =  list(set(map(lambda x: x['destination'], tickets_list[change])))
#     tickets = []
#     for point in tqdm(ponts_list, desc=f'for_{change + 1}_point_destination'):
#         if change + 1 < number_place: destination_list = get_destinations(routes, point) + final_destination
#         else: destination_list = final_destination
#         tickets = tickets + get_price_routes(datetime_start, datetime_end, point, destination_list)    
            
#     tickets_list.append(tickets)
# Out:
# HBox(children=(IntProgress(value=0, description='send_query', max=90, style=ProgressStyle(description_width='i…

# %%
# !git add ticket_base.json
# !git add browser_query.json
# !git commit -m "update jsons"
# !git push origin master

# %% [markdown]
# ### Нужно порабатать с кодом

# %%
df = pd.read_json('ticket_base.json')
df = df[(df['depart_date'] >= date_start) & (df['depart_date'] <= date_end)]

feature = list(df.columns).remove('found_at')

df.sort_values(by = 'found_at', ascending=False, inplace=True)
df.drop_duplicates(inplace = True, keep = 'first', subset = feature)

df.to_csv('routes_price.txt', index = False)

# %%
route_feature = ['depart_date', 'origin', 'destination', 'distance', 
                 'duration', 'number_of_changes', 'value']

df_route = df[df['origin'] == origin][route_feature]

for change in range(number_place):
    
    if change == 0:
        df_route = df_route.merge(df[route_feature], 
                                           how = 'left', left_on = 'destination', 
                                           right_on = 'origin', suffixes = ['_from', ''])
        
        df_route.rename(columns={x:x + '_' + str(change + 1) for x in route_feature}, inplace = True)

        df_route = df_route[df_route['depart_date_from'] <= df_route['depart_date_' + str(change + 1)]]
    else:
        df_route = df_route.merge(df[route_feature], 
                                           how = 'left', left_on = 'destination_' + str(change), 
                                           right_on = 'origin')
        
        df_route.rename(columns={x:x + '_' + str(change + 1) for x in route_feature}, inplace = True)
        df_route = df_route[df_route['depart_date_' + str(change)] <= df_route['depart_date_' + str(change+1)]]


value_list = list(filter(lambda x: x[:5] == 'value', list(df_route.columns)))
df_route['total_value'] =  df_route[value_list].sum(axis = 1)

#df_route = df_route[(df_route['depart_date_from'] >= date_start) & (df_route['depart_date_to'] <= date_end)]

df_route.sort_values(by = ['total_value', 'depart_date_from'] , inplace = True)

df_route = df_route[df_route['destination' + str(change+1)].isin(final_destination)]

df_route.reset_index(drop=True, inplace = True)
